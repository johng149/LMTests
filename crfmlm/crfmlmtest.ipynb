# %%
import torch

# %%
vocab_size = 4
embedding_dim = 16
batch_size = 2
phm_factor = 4
vocab_phm_factor = 2
question_len = 5
context_len = 10
answer_len = 3
num_heads = 2

# %%
mock_question_ids = torch.randint(0, vocab_size, (batch_size, question_len))
mock_context_ids = torch.randint(0, vocab_size, (batch_size, context_len))
mock_answer_ids = torch.randint(0, vocab_size, (batch_size, answer_len))

# %%
# need to add path using os and sys first
import os
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../")))
# and now we can import the model
from models.model import MainModel

# %%
model = MainModel(vocab_size, embedding_dim, num_heads, phm_factor, vocab_phm_factor)

# %%
print(f"Model trainable parameters: {sum(p.numel() for p in model.parameters() if p.requires_grad)}")
# Out:
# Model trainable parameters: 12808

# %%
logits = model(mock_question_ids, mock_context_ids, mock_answer_ids)

# %%
logits.shape
# Out:
# torch.Size([2, 3, 4])
