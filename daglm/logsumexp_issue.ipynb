# %%
import torch

# %%
from utils.logsumexp import logsumexp_infsafe as logsumexp

# %%
file = "transition_probs.pt"

# %%
# for whatever reason, the transition probs are causing trouble with the logsumexp
# function, so I saved it to disk and load it here for post-mortem analysis
matrix = torch.load(file)

# %%
matrix.shape
# Out:
# torch.Size([8, 100, 100])

# %%
batch_size, vertices, _ = matrix.shape

# %%
target_len = 25

# %%
dp = torch.log(torch.zeros(batch_size, target_len, vertices))

# %%
dp[:, 0, 0] = -0.03

# %%
matrix.shape
# Out:
# torch.Size([8, 100, 100])

# %%
dp[:, 0, :].unsqueeze(1).transpose(1,2).shape
# Out:
# torch.Size([8, 100, 1])

# %%
(dp[:, 0, :].unsqueeze(1).transpose(1,2) + matrix).shape
# Out:
# torch.Size([8, 100, 100])

# %%
logsumexp(dp[:, 0, :].unsqueeze(1).transpose(1,2) + matrix, dim=-1).shape
# Out:
# torch.Size([8, 100, 1])

# %%
dp.shape
# Out:
# torch.Size([8, 25, 100])
