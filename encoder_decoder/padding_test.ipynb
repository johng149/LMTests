# %%
import torch

# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../")))

# %%
from utils.tokenizer import prepare_tokenizer, pad_tensor

# %%
vocab, eos_idx, bos_idx, pad_idx, answer_pad_idx, vocab_size = prepare_tokenizer()

# %%
test_len = 7
test_t_1d = torch.tensor([1, 1, 1, 1])
test_t_1d_short = torch.tensor([1, 1])
test_t_2d = torch.tensor([[1, 1, 1, 1], [1, 1, 1, 1]])
test_t_2d_short = torch.tensor([[1, 1], [1, 1]])

# %%
print(f"eos_idx: {eos_idx}, bos_idx: {bos_idx}, pad_idx: {pad_idx}, answer_pad_idx: {answer_pad_idx}")
# Out:
# eos_idx: 8000, bos_idx: 8001, pad_idx: 8002, answer_pad_idx: 8003

# %%
pad_tensor(test_t_1d, test_len, eos_idx, bos_idx, pad_idx)
# Out:
# tensor([8001,    1,    1,    1,    1, 8000, 8002])

# %%
pad_tensor(test_t_1d_short, test_len, eos_idx, bos_idx, answer_pad_idx)
# Out:
# tensor([8001,    1,    1, 8000, 8003, 8003, 8003])

# %%
pad_tensor(test_t_2d, test_len, eos_idx, bos_idx, pad_idx)
# Out:
# tensor([[8001,    1,    1,    1,    1, 8000, 8002],
#         [8001,    1,    1,    1,    1, 8000, 8002]])

# %%
pad_tensor(test_t_2d_short, test_len, eos_idx, bos_idx, answer_pad_idx)
# Out:
# tensor([[8001,    1,    1, 8000, 8003, 8003, 8003],
#         [8001,    1,    1, 8000, 8003, 8003, 8003]])

# %%
test_t_1d_too_long = torch.randint(0, 1, (test_len + 1,))
test_t_2d_too_long = torch.randint(0, 1, (test_len + 1, test_len + 1))

# %%
pad_tensor(test_t_1d_too_long, test_len, eos_idx, bos_idx, pad_idx)
# Out:
# tensor([8001,    0,    0,    0,    0,    0, 8000])

# %%
pad_tensor(test_t_2d_too_long, test_len, eos_idx, bos_idx, answer_pad_idx)
# Out:
# tensor([[8001,    0,    0,    0,    0,    0, 8000],
#         [8001,    0,    0,    0,    0,    0, 8000],
#         [8001,    0,    0,    0,    0,    0, 8000],
#         [8001,    0,    0,    0,    0,    0, 8000],
#         [8001,    0,    0,    0,    0,    0, 8000],
#         [8001,    0,    0,    0,    0,    0, 8000],
#         [8001,    0,    0,    0,    0,    0, 8000],
#         [8001,    0,    0,    0,    0,    0, 8000]])

# %%
import torch
from torch.utils.data import DataLoader

# %%
from utils.load_data import load_data, prep_dolly_collate_fn, prep_squad_collate_fn

# %%
qc_len = 512 + 256
a_len = 100

# %%
squad_collate = prep_squad_collate_fn(qc_len, a_len, eos_idx, bos_idx, pad_idx, answer_pad_idx, pad_tensor)

# %%
squad, dolly = load_data()

# %%
batch_size = 2

# %%
squadDataloader = DataLoader(squad, batch_size=batch_size, shuffle=True, collate_fn=squad_collate)

# %%
for batch in squadDataloader:
    break

# %%
qc, a = batch

# %%
qc.shape
# Out:
# torch.Size([2, 768])

# %%
a.shape
# Out:
# torch.Size([2, 100])
